# %%
#transporting necessary package

import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Raga Bhimpalasi_.csv")

# %%
print(df.head())
# Out:
#          Song Name   P(S)=X1  P(r )=X2   P(R)=X3   P(g)=X4  P(G)=X5   P(M)=X6  \
# 0  Raag Bhimpalasi  0.211268         0  0.098592  0.126761        0  0.183099
#
#    P(m)=X7   P(P)=X8  P(d)=X9  P(D)=X10  P(n)=X11  P(N)=12
# 0        0  0.211268        0  0.028169  0.140845        0

# %%
x=pd.plotting.andrews_curves(df,'Song Name', color="Purple")
